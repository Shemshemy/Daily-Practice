# %%
# Implementation of a house with colour and size attributes
class house:
    def __init__(self, colour, size):
        self.colour = colour
        self.size = size

    def describe(self):
        print(f"This house is {self.colour} and has {self.size:,} rooms")

# %%
# A couple of instances of the class
mine = house("Red", 3)
brians = house("black", 5)

# %%
# Describing them
mine.describe()
brians.describe()
# Out:
# This house is Red and has 3 rooms
# This house is black and has 5 rooms
