# %%
class security:
    def __init__(self, password):
        self.password = password
        self.counter = 0


    def entry(self):
        if self.password == 'Kenya2026':
            print("Enter")
        else:
            self.counter += 1
            print(f'You have {self.counter} wrong entries')

# %%
Dennis = security("123")
Dennis.entry()
Dennis.entry()
Dennis.entry()
Dennis.entry()
# Out:
# You have 1 wrong entries
# You have 2 wrong entries
# You have 3 wrong entries
# You have 4 wrong entries
